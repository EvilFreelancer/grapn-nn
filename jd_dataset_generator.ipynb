# %% [markdown]
# # Генератор датасета JD_Analysis
#
# Проект [JD_Analysis](https://github.com/ZhongTr0n/JD_Analysis) содержит направленные ациклические графы, сохранённые в формате JSON, которые представляют собой древо информационных технологий, с перечислением их названий (вершины/nodes), связей (рёбра/edges) между ними и силой этих связей (веса/weights).
#
# Данный проект содержит два графа:
#
# | Название        | Вершин | Рёбер |
# |-----------------|--------|-------|
# | `jd_data.json`  | 249    | 668   |
# | `jd_data2.json` | 177    | 415   |
#
# Указанные графы имеют следующую структуру:
#
# ```json
# {
#   "nodes": [
#     {"id": "node1", "color": 1.23, "group": 1},
#     {"id": "node2", "color": 1.23, "group": 2},
#     {"id": "node3", "color": 1.23, "group": 2},
#     {"id": "node4", "color": 1.23, "group": 3}
#   ],
#   "links": [
#     {"source": "node1", "target": "node2", "value": 1.2, "group":1},
#     {"source": "node2", "target": "node3", "value": 3.1, "group":2},
#     {"source": "node3", "target": "node4", "value": 2.5, "group":3}
#   ]
# }
# ```
#
# В блоке `nodes` перечислен список вершин графа, каждый элемент указанного списка содержит поля
# - `id` которое содержит название технологии;
# - `color` для обозначения цвета узла (так как автор проекта JD_Analysis использовал собранные данные для визуализации взаимосвязей между технологиями);
# - `group`, которое скорее всего должно было представлять профессии к которым данные технологии относятся, но судя по тому, что на обоих графах в поле group всегда содержится число 0 можно предположить, что автор не стал развивать эту идею.
#
# В блоке `links` перечислен список рёбер графа, каждое ребро представлено несколькими полями, в частности:
# - `source` описывает из какой вершины начинается ребро;
# - `target` описывает в какую вершину данное ребро приходит;
# - `value` вес ребра;
# - `group`, которое, как и в случае с nodes, тоже всегда содержит 0 и не представляет ценности.
#
# В данном юпитер-блокноте из указанных JSON файлов мы соберём датасет, который в дальнейшем можно будет загрузить на площадку HuggingFace и использовать в дальнейшем при помощи стандартизированных загрузчиков данных.

# %% [markdown]
# ## Загрузка JSON файлов
#
# Данный блок позволяет скачать указанные выше JSON файлы, после чего сохранит их в директории, в которой находится текущий юпитер-блокнот, после чего прочитать содержимое и добавить в список объектов.

# %%
from simple_gnn.dataset.jd_dataset import load_jda

JD_ANALYSIS_GRAPHS = ["jd_data.json", "jd_data2.json"]

items = {}
for jd in JD_ANALYSIS_GRAPHS:
    items[jd] = {'object': load_jda(jd)}

items
# Out:
# {'jd_data.json': {'object': {'nodes': [{'id': '.net',
#      'color': 60.32785914264073,
#      'group': 0},
#     {'id': 'actionscript', 'color': 15.307012281730257, 'group': 0},
#     {'id': 'adobe', 'color': 17.150977832309312, 'group': 0},
#     {'id': 'agile', 'color': 52.356489380272656, 'group': 0},
#     {'id': 'aix', 'color': 15.228536030355718, 'group': 0},
#     {'id': 'ajax', 'color': 28.53085707112983, 'group': 0},
#     {'id': 'algo', 'color': 15.023140579703956, 'group': 0},
#     {'id': 'altova', 'color': 15.001870433034734, 'group': 0},
#     {'id': 'amazon', 'color': 15.37350727198416, 'group': 0},
#     {'id': 'android', 'color': 20.664544189867314, 'group': 0},
#     {'id': 'ant', 'color': 15.322450548102168, 'group': 0},
#     {'id': 'antlr', 'color': 15.000230050655402, 'group': 0},
#     {'id': 'apache', 'color': 21.549456823572623, 'group': 0},
#     {'id': 'apex', 'color': 15.084019073487719, 'group': 0},
#     {'id': 'apl', 'color': 15.000230050655402, 'group': 0},
#     {'id': 'app', 'color': 18.16895386260792, 'group': 0},
#     {'id': 'asp.net', 'color': 47.312114959040855, 'group': 0},
#     {'id': 'asterdata', 'color': 15.000230050655402, 'group': 0},
#     {'id': 'atom', 'color': 15.001562959343616, 'group': 0},
#     {'id': 'awk', 'color': 15.011680175164631, 'group': 0},
#     {'id': 'aws', 'color': 15.18753311067883, 'group': 0},
#     {'id': 'backbone', 'color': 15.500773271855241, 'group': 0},
#     {'id': 'bash', 'color': 15.942937349455098, 'group': 0},
#     {'id': 'bdd', 'color': 16.688077444746128, 'group': 0},
#     {'id': 'bigtable', 'color': 15.0, 'group': 0},
#     {'id': 'blackberry', 'color': 16.688077444746128, 'group': 0},
#     {'id': 'bluetooth', 'color': 15.016144294127562, 'group': 0},
#     {'id': 'boost', 'color': 15.132355718086476, 'group': 0},
#     {'id': 'c', 'color': 64.93029564183351, 'group': 0},
#     {'id': 'cache', 'color': 15.292302673178483, 'group': 0},
#     {'id': 'cake', 'color': 15.044989333955368, 'group': 0},
#     {'id': 'cassandra', 'color': 15.052736694752776, 'group': 0},
#     {'id': 'celery', 'color': 15.003260372136257, 'group': 0},
#     {'id': 'cellular', 'color': 15.010175589185618, 'group': 0},
#     {'id': 'centos', 'color': 15.432533521262032, 'group': 0},
#     {'id': 'cfengine', 'color': 15.002887295872192, 'group': 0},
#     {'id': 'cisco', 'color': 29.905064982628485, 'group': 0},
#     {'id': 'clojure', 'color': 15.023140579703956, 'group': 0},
#     {'id': 'cloud', 'color': 22.21486974205238, 'group': 0},
#     {'id': 'cmake', 'color': 15.000724903964302, 'group': 0},
#     {'id': 'cms', 'color': 20.142022700611626, 'group': 0},
#     {'id': 'codeigniter', 'color': 15.10826536176316, 'group': 0},
#     {'id': 'coffeescript', 'color': 15.020579703591684, 'group': 0},
#     {'id': 'confluence', 'color': 15.008809678880644, 'group': 0},
#     {'id': 'couch', 'color': 15.000990863593119, 'group': 0},
#     {'id': 'couchdb', 'color': 15.008174685529632, 'group': 0},
#     {'id': 'css', 'color': 50.59311249461327, 'group': 0},
#     {'id': 'cucumber', 'color': 15.207044130718494, 'group': 0},
#     {'id': 'cython', 'color': 15.0, 'group': 0},
#     {'id': 'database', 'color': 48.9129637594878, 'group': 0},
#     {'id': 'dell', 'color': 15.454189630376403, 'group': 0},
#     {'id': 'dhcp', 'color': 17.257759108507965, 'group': 0},
#     {'id': 'dhtml', 'color': 15.113858464890079, 'group': 0},
#     {'id': 'directx', 'color': 15.018254859999958, 'group': 0},
#     {'id': 'django', 'color': 15.10826536176316, 'group': 0},
#     {'id': 'dns', 'color': 21.240115296992826, 'group': 0},
#     {'id': 'dom', 'color': 15.05002842692525, 'group': 0},
#     {'id': 'dreamweaver', 'color': 15.264933487498386, 'group': 0},
#     {'id': 'spring', 'color': 27.28330806185226, 'group': 0},
#     {'id': 'sql', 'color': 70.0, 'group': 0},
#     {'id': 'squid', 'color': 15.006993195834085, 'group': 0},
#     {'id': 'ssas', 'color': 18.491157183062448, 'group': 0},
#     {'id': 'ssh', 'color': 15.04041468743381, 'group': 0},
#     {'id': 'ssis', 'color': 23.755224890230338, 'group': 0},
#     {'id': 'ssl', 'color': 15.338653567219309, 'group': 0},
#     {'id': 'ssrs', 'color': 22.572496880489613, 'group': 0},
#     {'id': 'stl', 'color': 15.088411108109042, 'group': 0},
#     {'id': 'svg', 'color': 15.007569662698614, 'group': 0},
#     {'id': 'svn', 'color': 17.610901229734807, 'group': 0},
#     {'id': 'symbian', 'color': 15.01422825628417, 'group': 0},
#     {'id': 'symfony', 'color': 15.146264787484363, 'group': 0},
#     {'id': 'systemc', 'color': 15.002193137798026, 'group': 0},
#     {'id': 'talend', 'color': 15.005421968211136, 'group': 0},
#     {'id': 'tck', 'color': 15.000230050655402, 'group': 0},
#     {'id': 'tcl', 'color': 15.01422825628417, 'group': 0},
#     {'id': 'tcp', 'color': 25.624230143740192, 'group': 0},
#     {'id': 'tdd', 'color': 26.150743973458873, 'group': 0},
#     {'id': 'tk', 'color': 15.0, 'group': 0},
#     {'id': 'tomcat', 'color': 16.95229704721892, 'group': 0},
#     {'id': 'toolchain', 'color': 15.004946868582142, 'group': 0},
#     {'id': 'ttl', 'color': 15.000724903964302, 'group': 0},
#     {'id': 'ubuntu', 'color': 15.169820395217943, 'group': 0},
#     {'id': 'udp', 'color': 15.044989333955368, 'group': 0},
#     {'id': 'ui', 'color': 22.947839501306824, 'group': 0},
#     {'id': 'umbraco', 'color': 15.240086882996813, 'group': 0},
#     {'id': 'umts', 'color': 15.018254859999958, 'group': 0},
#     {'id': 'unfuddle', 'color': 15.000471497141527, 'group': 0},
#     {'id': 'unix', 'color': 33.98235114792286, 'group': 0},
#     {'id': 'ux', 'color': 17.87644759055436, 'group': 0},
#     {'id': 'vagrant', 'color': 15.006443937146873, 'group': 0},
#     {'id': 'vb', 'color': 29.201354096146193, 'group': 0},
#     {'id': 'vb.net', 'color': 24.64458104444636, 'group': 0},
#     {'id': 'vbs', 'color': 15.278287331135928, 'group': 0},
#     {'id': 'vhdl', 'color': 15.102936242832008, 'group': 0},
#     {'id': 'vi', 'color': 15.008809678880644, 'group': 0},
#     {'id': 'vmware', 'color': 30.64363501840397, 'group': 0},
#     {'id': 'voip', 'color': 16.859933019327258, 'group': 0},
#     {'id': 'watir', 'color': 15.01248881708195, 'group': 0},
#     {'id': 'wcf', 'color': 26.703339287133048, 'group': 0},
#     {'id': 'weblogic', 'color': 15.579664673866942, 'group': 0},
#     {'id': 'wifi', 'color': 15.0978586485274, 'group': 0},
#     {'id': 'winrunner', 'color': 15.004062882450445, 'group': 0},
#     {'id': 'wordpress', 'color': 16.03914168647472, 'group': 0},
#     {'id': 'wpf', 'color': 19.899109479860833, 'group': 0},
#     {'id': 'xml', 'color': 41.62946305280514, 'group': 0},
#     {'id': 'yii', 'color': 15.013337516031015, 'group': 0},
#     {'id': 'yui', 'color': 15.030738720171806, 'group': 0},
#     {'id': 'zend', 'color': 16.261843773689655, 'group': 0},
#     {'id': 'zenoss', 'color': 15.00449419278311, 'group': 0}],
#    'links': [{'source': '.net',
#      'target': 'agile',
#      'value': 0.8372881714433367,
#      'group': 0},
#     {'source': '.net',
#      'target': 'ajax',
#      'value': 0.44773339967812265,
#      'group': 0},
#     {'source': '.net',
#      'target': 'asp.net',
#      'value': 2.972593634658615,
#      'group': 0},
#     {'source': '.net', 'target': 'c', 'value': 2.8562696820640907, 'group': 0},
#     {'source': '.net',
#      'target': 'css',
#      'value': 1.122948220895545,
#      'group': 0},
#     {'source': '.net',
#      'target': 'html',
#      'value': 1.2430995496749744,
#      'group': 0},
#     {'source': '.net',
#      'target': 'javascript',
#      'value': 1.478657578185328,
#      'group': 0},
#     {'source': '.net',
#      'target': 'jquery',
#      'value': 0.9910390193698609,
#      'group': 0},
#     {'source': '.net',
#      'target': 'microsoft',
#      'value': 0.23970292350123418,
#      'group': 0},
#     {'source': '.net',
#      'target': 'mvc',
#      'value': 2.459239133169448,
#      'group': 0},
#     {'source': '.net',
#      'target': 'nhibernate',
#      'value': 0.7119146880451459,
#      'group': 0},
#     {'source': '.net',
#      'target': 'nunit',
#      'value': 0.7714031875426703,
#      'group': 0},
#     {'source': '.net',
#      'target': 'scrum',
#      'value': 0.36733840916906646,
#      'group': 0},
#     {'source': '.net',
#      'target': 'server',
#      'value': 2.2422817140847973,
#      'group': 0},
#     {'source': '.net',
#      'target': 'sharepoint',
#      'value': 0.12848628029498468,
#      'group': 0},
#     {'source': '.net',
#      'target': 'silverlight',
#      'value': 0.2786910566659671,
#      'group': 0},
#     {'source': '.net',
#      'target': 'sql',
#      'value': 2.684805996372943,
#      'group': 0},
#     {'source': '.net',
#      'target': 'tdd',
#      'value': 0.884277647253485,
#      'group': 0},
#     {'source': '.net', 'target': 'vb', 'value': 2.482629877702873, 'group': 0},
#     {'source': '.net',
#      'target': 'vb.net',
#      'value': 2.4053643217112866,
#      'group': 0},
#     {'source': '.net',
#      'target': 'wcf',
#      'value': 2.413000883912463,
#      'group': 0},
#     {'source': '.net',
#      'target': 'wpf',
#      'value': 1.6023694892570488,
#      'group': 0},
#     {'source': '.net',
#      'target': 'xml',
#      'value': 0.7747903574885888,
#      'group': 0},
#     {'source': 'actionscript',
#      'target': 'flash',
#      'value': 2.6931692939066023,
#      'group': 0},
#     {'source': 'actionscript',
#      'target': 'photoshop',
#      'value': 0.16005110823976493,
#      'group': 0},
#     {'source': 'adobe',
#      'target': 'css',
#      'value': 0.14760024858171933,
#      'group': 0},
#     {'source': 'adobe',
#      'target': 'dreamweaver',
#      'value': 1.2945175396513016,
#      'group': 0},
#     {'source': 'adobe',
#      'target': 'flash',
#      'value': 0.6489976933133703,
#      'group': 0},
#     {'source': 'adobe',
#      'target': 'photoshop',
#      'value': 2.643313791723149,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'asp.net',
#      'value': 0.400605756752652,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'bdd',
#      'value': 1.1620661912741723,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'c',
#      'value': 0.40302860527273043,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'java',
#      'value': 0.7987484836276949,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'kanban',
#      'value': 0.899058057158709,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'mvc',
#      'value': 1.2616272543072782,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'nhibernate',
#      'value': 0.2999971015003321,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'nunit',
#      'value': 0.8337388869692142,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'objectorientated',
#      'value': 0.24371692324802344,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'scrum',
#      'value': 2.7952416608021826,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'selenium',
#      'value': 0.2914082213168622,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'spring',
#      'value': 0.46569090253799794,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'tdd',
#      'value': 2.5699722691747904,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'wcf',
#      'value': 1.0805429133497644,
#      'group': 0},
#     {'source': 'agile',
#      'target': 'wpf',
#      'value': 0.1763956080542745,
#      'group': 0},
#     {'source': 'aix',
#      'target': 'ibm',
#      'value': 0.4605268294295711,
#      'group': 0},
#     {'source': 'aix',
#      'target': 'linux',
#      'value': 0.18937478579349326,
#      'group': 0},
#     {'source': 'aix',
#      'target': 'red',
#      'value': 0.11157752199341114,
#      'group': 0},
#     {'source': 'aix',
#      'target': 'solaris',
#      'value': 1.9881733243733282,
#      'group': 0},
#     {'source': 'aix',
#      'target': 'unix',
#      'value': 0.9139928237286966,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'asp.net',
#      'value': 0.9366879231724902,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'css',
#      'value': 2.3977475681658067,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'html',
#      'value': 2.150204951670193,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'javascript',
#      'value': 2.522021757766529,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'jquery',
#      'value': 2.375015646308286,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'json',
#      'value': 1.188657486216788,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'jsp',
#      'value': 0.1440842406603527,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'mvc',
#      'value': 1.0029450395848654,
#      'group': 0},
#     {'source': 'ajax',
#      'target': 'xml',
#      'value': 1.5102212002618636,
#      'group': 0},
#     {'source': 'algo',
#      'target': 'clojure',
#      'value': 0.40789322178171816,
#      'group': 0},
#     {'source': 'algo', 'target': 'fx', 'value': 0.262040202467176, 'group': 0},
#     {'source': 'algo',
#      'target': 'haskell',
#      'value': 0.9027772151813013,
#      'group': 0},
#     {'source': 'algo',
#      'target': 'juice',
#      'value': 1.1489251360616441,
#      'group': 0},
#     {'source': 'algo',
#      'target': 'scala',
#      'value': 0.161848353715205,
#      'group': 0},
#     {'source': 'amazon',
#      'target': 'aws',
#      'value': 2.726840552122973,
#      'group': 0},
#     {'source': 'amazon',
#      'target': 'cloud',
#      'value': 0.17823536016556746,
#      'group': 0},
#     {'source': 'android',
#      'target': 'app',
#      'value': 1.447582023162509,
#      'group': 0},
#     {'source': 'android',
#      'target': 'blackberry',
#      'value': 0.785004812471721,
#      'group': 0},
#     {'source': 'android',
#      'target': 'ios',
#      'value': 2.8650788999093137,
#      'group': 0},
#     {'source': 'android',
#      'target': 'java',
#      'value': 0.1216700316560432,
#      'group': 0},
#     {'source': 'android',
#      'target': 'objectivec',
#      'value': 0.5863596076352994,
#      'group': 0},
#     {'source': 'ant',
#      'target': 'eclipse',
#      'value': 0.9481687919722591,
#      'group': 0},
#     {'source': 'ant',
#      'target': 'java',
#      'value': 0.2558847904771661,
#      'group': 0},
#     {'source': 'ant',
#      'target': 'junit',
#      'value': 2.2785319656888916,
#      'group': 0},
#     {'source': 'ant',
#      'target': 'maven',
#      'value': 2.55390566617119,
#      'group': 0},
#     {'source': 'ant',
#      'target': 'tomcat',
#      'value': 0.4054577548201236,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'centos',
#      'value': 0.6187437838980394,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'jboss',
#      'value': 0.43259898490810655,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'lamp',
#      'value': 0.781591147014269,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'linux',
#      'value': 2.0343937932140097,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'mysql',
#      'value': 2.0277393087208266,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'nginx',
#      'value': 0.5026003701106715,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'perl',
#      'value': 0.34203530557073053,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'php',
#      'value': 1.0889360932838577,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'tomcat',
#      'value': 2.490467382049099,
#      'group': 0},
#     {'source': 'apache',
#      'target': 'ubuntu',
#      'value': 0.5215645356088913,
#      'group': 0},
#     {'source': 'apex',
#      'target': 'salesforce',
#      'value': 2.6186758826534744,
#      'group': 0},
#     {'source': 'app',
#      'target': 'ios',
#      'value': 1.1664693464279137,
#      'group': 0},
#     {'source': 'app',
#      'target': 'json',
#      'value': 0.14058644959063066,
#      'group': 0},
#     {'source': 'app',
#      'target': 'objectivec',
#      'value': 0.19500993555151633,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'c',
#      'value': 2.7608634503242966,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'css',
#      'value': 1.7573480450464258,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'html',
#      'value': 1.787259652773583,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'javascript',
#      'value': 2.0544612635142467,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'jquery',
#      'value': 1.4943779045483194,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'mvc',
#      'value': 2.7015543416098473,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'nhibernate',
#      'value': 0.8732926760696009,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'nunit',
#      'value': 0.9558725540187083,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'scrum',
#      'value': 0.282908110575684,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'server',
#      'value': 2.108745285875401,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'sql',
#      'value': 2.602356940485363,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'tdd',
#      'value': 0.9831530557196353,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'vb',
#      'value': 2.2858386788990925,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'vb.net',
#      'value': 2.2279129144880407,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'wcf',
#      'value': 2.4360299382779793,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'wpf',
#      'value': 0.6613209975490756,
#      'group': 0},
#     {'source': 'asp.net',
#      'target': 'xml',
#      'value': 0.8479915040372443,
#      'group': 0},
#     {'source': 'awk',
#      'target': 'cfengine',
#      'value': 1.87310851981966,
#      'group': 0},
#     {'source': 'awk',
#      'target': 'perl',
#      'value': 0.3720171475067665,
#      'group': 0},
#     {'source': 'awk',
#      'target': 'sed',
#      'value': 2.9363824220346664,
#      'group': 0},
#     {'source': 'awk',
#      'target': 'shell',
#      'value': 0.14936511349100307,
#      'group': 0},
#     {'source': 'aws',
#      'target': 'cloud',
#      'value': 0.2765907301951396,
#      'group': 0},
#     {'source': 'aws',
#      'target': 'git',
#      'value': 0.13884435586111177,
#      'group': 0},
#     {'source': 'aws',
#      'target': 'nosql',
#      'value': 0.3488646140592082,
#      'group': 0},
#     {'source': 'aws',
#      'target': 'puppet',
#      'value': 0.7151471480877777,
#      'group': 0},
#     {'source': 'aws',
#      'target': 'ruby',
#      'value': 0.5719426197306172,
#      'group': 0},
#     {'source': 'aws',
#      'target': 'samba',
#      'value': 0.204499977353802,
#      'group': 0},
#     {'source': 'aws',
#      'target': 'sinatra',
#      'value': 0.29569150751351875,
#      'group': 0},
#     {'source': 'backbone',
#      'target': 'knockout',
#      'value': 1.4682452052824158,
#      'group': 0},
#     {'source': 'backbone',
#      'target': 'node',
#      'value': 1.8856294620425293,
#      'group': 0},
#     {'source': 'bash',
#      'target': 'centos',
#      'value': 0.9870909170076344,
#      'group': 0},
#     {'source': 'bash',
#      'target': 'linux',
#      'value': 1.2477134457811196,
#      'group': 0},
#     {'source': 'bash',
#      'target': 'perl',
#      'value': 2.115610440111428,
#      'group': 0},
#     {'source': 'bash',
#      'target': 'postfix',
#      'value': 0.3933748541243641,
#      'group': 0},
#     {'source': 'bash',
#      'target': 'puppet',
#      'value': 1.5476725217910132,
#      'group': 0},
#     {'source': 'bash',
#      'target': 'python',
#      'value': 0.6247318669972712,
#      'group': 0},
#     {'source': 'bash',
#      'target': 'shell',
#      'value': 0.5520708036593198,
#      'group': 0},
#     {'source': 'bash',
#      'target': 'ubuntu',
#      'value': 0.5748110587383478,
#      'group': 0},
#     {'source': 'bdd',
#      'target': 'cucumber',
#      'value': 1.3087974645603837,
#      'group': 0},
#     {'source': 'bdd',
#      'target': 'kanban',
#      'value': 1.8359335853133285,
#      'group': 0},
#     {'source': 'bdd',
#      'target': 'mvc',
#      'value': 0.4787190576195589,
#      'group': 0},
#     {'source': 'bdd',
#      'target': 'nhibernate',
#      'value': 1.4220531080285708,
#      'group': 0},
#     {'source': 'bdd',
#      'target': 'nunit',
#      'value': 0.6428838861065937,
#      'group': 0},
#     {'source': 'bdd',
#      'target': 'scrum',
#      'value': 1.396853579870744,
#      'group': 0},
#     {'source': 'bdd',
#      'target': 'selenium',
#      'value': 0.6737729980897472,
#      'group': 0},
#     {'source': 'bdd',
#      'target': 'specflow',
#      'value': 0.35344713899304303,
#      'group': 0},
#     {'source': 'bdd', 'target': 'tdd', 'value': 2.743807817601475, 'group': 0},
#     {'source': 'bdd',
#      'target': 'wcf',
#      'value': 0.2892749074978861,
#      'group': 0},
#     {'source': 'blackberry',
#      'target': 'ios',
#      'value': 0.3814478531251625,
#      'group': 0},
#     {'source': 'blackberry',
#      'target': 'symbian',
#      'value': 0.113248703710251,
#      'group': 0},
#     {'source': 'bluetooth',
#      'target': 'wifi',
#      'value': 0.6990684781927737,
#      'group': 0},
#     {'source': 'boost',
#      'target': 'stl',
#      'value': 2.7694245481293422,
#      'group': 0},
#     {'source': 'c',
#      'target': 'html',
#      'value': 0.21025344113026184,
#      'group': 0},
#     {'source': 'c',
#      'target': 'javascript',
#      'value': 0.5776869576068118,
#      'group': 0},
#     {'source': 'c', 'target': 'mvc', 'value': 1.6302553480283555, 'group': 0},
#     {'source': 'c',
#      'target': 'nhibernate',
#      'value': 0.16545687894411418,
#      'group': 0},
#     {'source': 'c',
#      'target': 'nunit',
#      'value': 0.2497771543431699,
#      'group': 0},
#     {'source': 'c',
#      'target': 'server',
#      'value': 0.8056740495110416,
#      'group': 0},
#     {'source': 'c', 'target': 'sql', 'value': 1.8606524500749033, 'group': 0},
#     {'source': 'c', 'target': 'tdd', 'value': 0.3650081382758956, 'group': 0},
#     {'source': 'c', 'target': 'vb', 'value': 0.9753079501769859, 'group': 0},
#     {'source': 'c',
#      'target': 'vb.net',
#      'value': 0.695877724984657,
#      'group': 0},
#     {'source': 'c', 'target': 'wcf', 'value': 1.775248376132199, 'group': 0},
#     {'source': 'c', 'target': 'wpf', 'value': 1.2247633361302193, 'group': 0},
#     {'source': 'cache',
#      'target': 'guice',
#      'value': 0.7248950550772164,
#      'group': 0},
#     {'source': 'cake',
#      'target': 'codeigniter',
#      'value': 0.8196335762835416,
#      'group': 0},
#     {'source': 'cake',
#      'target': 'zend',
#      'value': 1.647161519956655,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'cfengine',
#      'value': 0.23372088457306767,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'hadoop',
#      'value': 2.626867197642871,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'hbase',
#      'value': 2.3825732816466885,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'mapreduce',
#      'value': 0.7781863363427696,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'mongodb',
#      'value': 1.6415114862324198,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'nosql',
#      'value': 2.4206573062850936,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'pig',
#      'value': 1.1931297965299903,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'redis',
#      'value': 0.435105037228509,
#      'group': 0},
#     {'source': 'cassandra',
#      'target': 'scala',
#      'value': 0.23570972076045976,
#      'group': 0},
#     {'source': 'cellular',
#      'target': 'tck',
#      'value': 1.4838840827807966,
#      'group': 0},
#     {'source': 'centos',
#      'target': 'cfengine',
#      'value': 0.18192923059076008,
#      'group': 0},
#     {'source': 'centos',
#      'target': 'linux',
#      'value': 1.0433085012325969,
#      'group': 0},
#     {'source': 'centos',
#      'target': 'puppet',
#      'value': 0.855173532579294,
#      'group': 0},
#     {'source': 'centos',
#      'target': 'pxe',
#      'value': 0.3626839119264057,
#      'group': 0},
#     {'source': 'centos',
#      'target': 'red',
#      'value': 1.0351517232332783,
#      'group': 0},
#     {'source': 'centos',
#      'target': 'ubuntu',
#      'value': 2.330079741534654,
#      'group': 0},
#     {'source': 'cisco',
#      'target': 'dhcp',
#      'value': 0.2457317558244608,
#      'group': 0},
#     {'source': 'cisco',
#      'target': 'dns',
#      'value': 0.4708818706644011,
#      'group': 0},
#     {'source': 'cisco',
#      'target': 'hardware',
#      'value': 0.21799479534662036,
#      'group': 0},
#     {'source': 'cisco',
#      'target': 'hp',
#      'value': 1.3040251212021094,
#      'group': 0},
#     {'source': 'cisco', 'target': 'ip', 'value': 1.8482609166963, 'group': 0},
#     {'source': 'cisco',
#      'target': 'networking',
#      'value': 2.59422920322011,
#      'group': 0},
#     {'source': 'cisco',
#      'target': 'security',
#      'value': 0.9290835589606867,
#      'group': 0},
#     {'source': 'cisco',
#      'target': 'tcp',
#      'value': 0.5633818686196024,
#      'group': 0},
#     {'source': 'cisco',
#      'target': 'vmware',
#      'value': 1.289782237321232,
#      'group': 0},
#     {'source': 'cisco',
#      'target': 'voip',
#      'value': 1.716119046931099,
#      'group': 0},
#     {'source': 'clojure',
#      'target': 'erlang',
#      'value': 2.7099611960476766,
#      'group': 0},
#     {'source': 'clojure',
#      'target': 'guice',
#      'value': 0.420165894333156,
#      'group': 0},
#     {'source': 'clojure',
#      'target': 'haskell',
#      'value': 2.4283336404789133,
#      'group': 0},
#     {'source': 'clojure',
#      'target': 'juice',
#      'value': 0.6459368198747031,
#      'group': 0},
#     {'source': 'clojure',
#      'target': 'kafka',
#      'value': 0.5106856691716049,
#      'group': 0},
#     {'source': 'clojure',
#      'target': 'scala',
#      'value': 2.263975349263984,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'css',
#      'value': 1.0721932194706245,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'drupal',
#      'value': 1.3670429568745086,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'html',
#      'value': 0.9675034910512393,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'javascript',
#      'value': 0.5436642896692151,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'joomla',
#      'value': 0.5408766429876987,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'jquery',
#      'value': 0.5270464992991245,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'php',
#      'value': 0.4760998738807697,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'umbraco',
#      'value': 2.1571779287785318,
#      'group': 0},
#     {'source': 'cms',
#      'target': 'wordpress',
#      'value': 1.4996452925110237,
#      'group': 0},
#     {'source': 'codeigniter',
#      'target': 'drupal',
#      'value': 0.3064975738989252,
#      'group': 0},
#     {'source': 'codeigniter',
#      'target': 'joomla',
#      'value': 0.2641026878299474,
#      'group': 0},
#     {'source': 'codeigniter',
#      'target': 'mysql',
#      'value': 0.1636502732314437,
#      'group': 0},
#     {'source': 'codeigniter',
#      'target': 'php',
#      'value': 0.6706478594137737,
#      'group': 0},
#     {'source': 'codeigniter',
#      'target': 'symfony',
#      'value': 0.7884273557434941,
#      'group': 0},
#     {'source': 'codeigniter',
#      'target': 'wordpress',
#      'value': 0.33301194407531304,
#      'group': 0},
#     {'source': 'codeigniter',
#      'target': 'yii',
#      'value': 1.710290142679333,
#      'group': 0},
#     {'source': 'codeigniter',
#      'target': 'zend',
#      'value': 1.8236701232878785,
#      'group': 0},
#     {'source': 'coffeescript',
#      'target': 'antlr',
#      'value': 0.9714006529997565,
#      'group': 0},
#     {'source': 'coffeescript',
#      'target': 'atom',
#      'value': 1.1358860764852687,
#      'group': 0},
#     {'source': 'coffeescript',
#      'target': 'cmake',
#      'value': 0.10493603199729774,
#      'group': 0},
#     {'source': 'coffeescript',
#      'target': 'rspec',
#      'value': 0.41278317370825446,
#      'group': 0},
#     {'source': 'coffeescript',
#      'target': 'sass',
#      'value': 2.1018979393220696,
#      'group': 0},
#     {'source': 'coffeescript',
#      'target': 'sinatra',
#      'value': 1.0515077605613457,
#      'group': 0},
#     {'source': 'confluence',
#      'target': 'jira',
#      'value': 1.5803200801049946,
#      'group': 0},
#     {'source': 'confluence',
#      'target': 'jpa',
#      'value': 0.7579421407371255,
#      'group': 0},
#     {'source': 'confluence',
#      'target': 'rake',
#      'value': 0.8126356844458941,
#      'group': 0},
#     {'source': 'couchdb',
#      'target': 'hypertable',
#      'value': 1.613480395072417,
#      'group': 0},
#     {'source': 'couchdb',
#      'target': 'mongodb',
#      'value': 1.4630592667337723,
#      'group': 0},
#     {'source': 'couchdb',
#      'target': 'nosql',
#      'value': 0.36036571444151555,
#      'group': 0},
#     {'source': 'couchdb',
#      'target': 'redis',
#      'value': 0.6926952483452429,
#      'group': 0},
#     {'source': 'css',
#      'target': 'drupal',
#      'value': 0.5052884728715141,
#      'group': 0},
#     {'source': 'css',
#      'target': 'flash',
#      'value': 0.17090493529173822,
#      'group': 0},
#     {'source': 'css',
#      'target': 'frontend',
#      'value': 1.3425531975121445,
#      'group': 0},
#     {'source': 'css',
#      'target': 'html',
#      'value': 2.990840807186023,
#      'group': 0},
#     {'source': 'css',
#      'target': 'javascript',
#      'value': 2.963505531850927,
#      'group': 0},
#     {'source': 'css',
#      'target': 'jquery',
#      'value': 2.829978894199185,
#      'group': 0},
#     {'source': 'css',
#      'target': 'json',
#      'value': 0.27032238280474036,
#      'group': 0},
#     {'source': 'css',
#      'target': 'mvc',
#      'value': 1.8297938913533691,
#      'group': 0},
#     {'source': 'css',
#      'target': 'mysql',
#      'value': 1.6928939915271508,
#      'group': 0},
#     {'source': 'css',
#      'target': 'objectorientated',
#      'value': 0.31965146268652594,
#      'group': 0},
#     {'source': 'css',
#      'target': 'photoshop',
#      'value': 1.4527277105218261,
#      'group': 0},
#     {'source': 'css', 'target': 'php', 'value': 2.300509161768417, 'group': 0},
#     {'source': 'css', 'target': 'ui', 'value': 0.633772517143629, 'group': 0},
#     {'source': 'css',
#      'target': 'wordpress',
#      'value': 0.7380109803363808,
#      'group': 0},
#     {'source': 'css', 'target': 'xml', 'value': 2.185251653503357, 'group': 0},
#     {'source': 'css',
#      'target': 'zend',
#      'value': 0.1672681830404631,
#      'group': 0},
#     {'source': 'cucumber',
#      'target': 'lucene',
#      'value': 0.7413113082003666,
#      'group': 0},
#     {'source': 'cucumber',
#      'target': 'rspec',
#      'value': 2.0950683542596718,
#      'group': 0},
#     {'source': 'cucumber',
#      'target': 'ruby',
#      'value': 0.45283084330320955,
#      'group': 0},
#     {'source': 'cucumber',
#      'target': 'selenium',
#      'value': 2.3078730303936763,
#      'group': 0},
#     {'source': 'database',
#      'target': 'oracle',
#      'value': 0.9989660539208429,
#      'group': 0},
#     {'source': 'database',
#      'target': 'server',
#      'value': 1.0109340819000647,
#      'group': 0},
#     {'source': 'database',
#      'target': 'sql',
#      'value': 1.968620354652579,
#      'group': 0},
#     {'source': 'database',
#      'target': 'ssas',
#      'value': 0.18378337382327284,
#      'group': 0},
#     {'source': 'database',
#      'target': 'ssis',
#      'value': 0.9636164380414296,
#      'group': 0},
#     {'source': 'database',
#      'target': 'ssrs',
#      'value': 0.3743656465137647,
#      'group': 0},
#     {'source': 'dell',
#      'target': 'hp',
#      'value': 1.7336968717911678,
#      'group': 0},
#     {'source': 'dhcp',
#      'target': 'dns',
#      'value': 2.909469830992994,
#      'group': 0},
#     {'source': 'dhcp',
#      'target': 'ip',
#      'value': 1.7632993313314516,
#      'group': 0},
#     {'source': 'dhcp',
#      'target': 'networking',
#      'value': 1.110110783787441,
#      'group': 0},
#     {'source': 'dhcp',
#      'target': 'tcp',
#      'value': 1.981638732225578,
#      'group': 0},
#     {'source': 'dhcp',
#      'target': 'vmware',
#      'value': 0.5805703357366381,
#      'group': 0},
#     {'source': 'dhtml',
#      'target': 'xml',
#      'value': 0.10991067519356126,
#      'group': 0},
#     {'source': 'directx',
#      'target': 'opencl',
#      'value': 1.4169869882316433,
#      'group': 0},
#     {'source': 'directx',
#      'target': 'opengl',
#      'value': 2.891644251088421,
#      'group': 0},
#     {'source': 'django',
#      'target': 'celery',
#      'value': 1.5584985602366979,
#      'group': 0},
#     {'source': 'django',
#      'target': 'flask',
#      'value': 0.4451945903556592,
#      'group': 0},
#     {'source': 'django',
#      'target': 'gunicorn',
#      'value': 0.45027881160357763,
#      'group': 0},
#     {'source': 'django',
#      'target': 'python',
#      'value': 1.473444630741271,
#      'group': 0},
#     {'source': 'django',
#      'target': 'unfuddle',
#      'value': 0.11828837124623215,
#      'group': 0},
#     {'source': 'dns',
#      'target': 'ftp',
#      'value': 0.5133947991199932,
#      'group': 0},
#     {'source': 'dns',
#      'target': 'hardware',
#      'value': 0.2518077475754408,
#      'group': 0},
#     {'source': 'dns',
#      'target': 'hyperv',
#      'value': 0.10328641271228649,
#      'group': 0},
#     {'source': 'dns',
#      'target': 'iis',
#      'value': 0.24170731699250622,
#      'group': 0},
#     {'source': 'dns', 'target': 'ip', 'value': 2.0211020854492086, 'group': 0},
#     {'source': 'dns',
#      'target': 'iscsi',
#      'value': 0.1931266714803253,
#      'group': 0},
#     {'source': 'dns',
#      'target': 'networking',
#      'value': 1.5968356426194437,
#      'group': 0},
#     {'source': 'dns',
#      'target': 'server',
#      'value': 0.16908419773943165,
#      'group': 0},
#     {'source': 'dns',
#      'target': 'tcp',
#      'value': 2.3226582704066545,
#      'group': 0},
#     {'source': 'dns',
#      'target': 'vmware',
#      'value': 0.7545986737711501,
#      'group': 0},
#     {'source': 'dom',
#      'target': 'yui',
#      'value': 0.8408466864319681,
#      'group': 0},
#     {'source': 'dreamweaver',
#      'target': 'flash',
#      'value': 0.6800476789334023,
#      'group': 0},
#     {'source': 'dreamweaver',
#      'target': 'photoshop',
#      'value': 2.545903607789395,
#      'group': 0},
#     {'source': 'drupal',
#      'target': 'html',
#      'value': 0.3174448880691336,
#      'group': 0},
#     {'source': 'drupal',
#      'target': 'joomla',
#      'value': 1.7692660949429073,
#      'group': 0},
#     {'source': 'drupal',
#      'target': 'jquery',
#      'value': 0.13020143609729726,
#      'group': 0},
#     {'source': 'drupal',
#      'target': 'mysql',
#      'value': 0.9102445732791357,
#      'group': 0},
#     {'source': 'drupal',
#      'target': 'php',
#      'value': 1.8919143658466482,
#      'group': 0},
#     {'source': 'drupal',
#      'target': 'wordpress',
#      'value': 2.2136185613363497,
#      'group': 0},
#     {'source': 'drupal',
#      'target': 'zend',
#      'value': 0.12677557347506205,
#      'group': 0},
#     {'source': 'eclipse',
#      'target': 'iwebkit',
#      'value': 0.3767202531895948,
#      'group': 0},
#     {'source': 'eclipse',
#      'target': 'j',
#      'value': 0.21994273317947582,
#      'group': 0},
#     {'source': 'eclipse',
#      'target': 'java',
#      'value': 0.8953485463463148,
#      'group': 0},
#     {'source': 'eclipse',
#      'target': 'jprofile',
#      'value': 0.3767202531895948,
#      'group': 0},
#     {'source': 'eclipse',
#      'target': 'junit',
#      'value': 0.6769062642173528,
#      'group': 0},
#     {'source': 'eclipse',
#      'target': 'maven',
#      'value': 0.8769448268613821,
#      'group': 0},
#     {'source': 'eclipse',
#      'target': 'spring',
#      'value': 0.17456062811862505,
#      'group': 0},
#     {'source': 'eclipse',
#      'target': 'tomcat',
#      'value': 0.6307511366423206,
#      'group': 0},
#     {'source': 'ejb',
#      'target': 'hibernate',
#      'value': 0.43761760696177976,
#      'group': 0},
#     {'source': 'ejb', 'target': 'j', 'value': 1.22020897084544, 'group': 0},
#     {'source': 'ejb',
#      'target': 'java',
#      'value': 0.11660411701896002,
#      'group': 0},
#     {'source': 'ejb',
#      'target': 'jboss',
#      'value': 0.6009650422450481,
#      'group': 0},
#     {'source': 'ejb',
#      'target': 'jpa',
#      'value': 0.27240640737811306,
#      'group': 0},
#     {'source': 'ejb', 'target': 'jsp', 'value': 1.084734053432528, 'group': 0},
#     {'source': 'ejb',
#      'target': 'junit',
#      'value': 0.2978415087859733,
#      'group': 0},
#     {'source': 'encryption',
#      'target': 'pki',
#      'value': 0.7512638795016329,
#      'group': 0},
#     {'source': 'erlang',
#      'target': 'guice',
#      'value': 0.4226396122989077,
#      'group': 0},
#     {'source': 'erlang',
#      'target': 'haskell',
#      'value': 2.803892164957417,
#      'group': 0},
#     {'source': 'erlang',
#      'target': 'juice',
#      'value': 0.11997700566145322,
#      'group': 0},
#     {'source': 'erlang',
#      'target': 'lisp',
#      'value': 1.898215614605976,
#      'group': 0},
#     {'source': 'erlang',
#      'target': 'ocaml',
#      'value': 1.2111356506531414,
#      'group': 0},
#     {'source': 'erlang',
#      'target': 'rspec',
#      'value': 0.6675308271074466,
#      'group': 0},
#     {'source': 'erlang',
#      'target': 'scala',
#      'value': 2.271244205531443,
#      'group': 0},
#     {'source': 'esx',
#      'target': 'vmware',
#      'value': 1.7395866492003969,
#      'group': 0},
#     {'source': 'exim',
#      'target': 'postfix',
#      'value': 1.0973729857527017,
#      'group': 0},
#     {'source': 'exim',
#      'target': 'pxe',
#      'value': 1.531538543837548,
#      'group': 0},
#     {'source': 'exim',
#      'target': 'qmail',
#      'value': 2.610505815305888,
#      'group': 0},
#     {'source': 'exim',
#      'target': 'squid',
#      'value': 1.0069343732740097,
#      'group': 0},
#     {'source': 'exim',
#      'target': 'ssh',
#      'value': 1.238497621660881,
#      'group': 0},
#     {'source': 'extjs',
#      'target': 'node',
#      'value': 0.3108594469785373,
#      'group': 0},
#     {'source': 'flash',
#      'target': 'html',
#      'value': 0.4631055128326437,
#      'group': 0},
#     {'source': 'flash',
#      'target': 'photoshop',
#      'value': 1.5422805548850957,
#      'group': 0},
#     {'source': 'fpga',
#      'target': 'vhdl',
#      'value': 2.9005454664827304,
#      'group': 0},
#     {'source': 'frontend',
#      'target': 'html',
#      'value': 1.1402211458230749,
#      'group': 0},
#     {'source': 'frontend',
#      'target': 'javascript',
#      'value': 0.9597394677485169,
#      'group': 0},
#     {'source': 'frontend',
#      'target': 'jquery',
#      'value': 0.7054749004695585,
#      'group': 0},
#     {'source': 'frontend',
#      'target': 'photoshop',
#      'value': 0.1458399615964304,
#      'group': 0},
#     {'source': 'ftp',
#      'target': 'ssh',
#      'value': 0.3152440371367856,
#      'group': 0},
#     {'source': 'gcc',
#      'target': 'mpeg',
#      'value': 0.4401367110575527,
#      'group': 0},
#     {'source': 'gcc',
#      'target': 'symbian',
#      'value': 0.11492423161776623,
#      'group': 0},
#     {'source': 'gcc',
#      'target': 'toolchain',
#      'value': 2.344980636357855,
#      'group': 0},
#     {'source': 'git',
#      'target': 'javascript',
#      'value': 0.10824815206626016,
#      'group': 0},
#     {'source': 'git',
#      'target': 'jquery',
#      'value': 0.31304889504268274,
#      'group': 0},
#     {'source': 'git',
#      'target': 'json',
#      'value': 0.5079835664981823,
#      'group': 0},
#     {'source': 'git',
#      'target': 'mysql',
#      'value': 0.35115290098755614,
#      'group': 0},
#     {'source': 'git',
#      'target': 'ruby',
#      'value': 0.22189573695408954,
#      'group': 0},
#     {'source': 'git',
#      'target': 'sass',
#      'value': 0.20833063657663314,
#      'group': 0},
#     {'source': 'git',
#      'target': 'svn',
#      'value': 2.0144820786248734,
#      'group': 0},
#     {'source': 'google',
# ...
#      'target': 'struts',
#      'value': 1.3828525651914727,
#      'group': 0},
#     {'source': 'java',
#      'target': 'tomcat',
#      'value': 0.3879303845385711,
#      'group': 0},
#     {'source': 'java',
#      'target': 'web',
#      'value': 0.14955366874203257,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'jquery',
#      'value': 2.781446409681797,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'json',
#      'value': 0.301273764272035,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'mvc',
#      'value': 0.7628694723197689,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'mysql',
#      'value': 1.7481199150737865,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'net',
#      'value': 1.711509064784781,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'node.js',
#      'value': 1.9200967919977652,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'php',
#      'value': 1.4143150852250799,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'pmp',
#      'value': 0.7682754747530639,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'python',
#      'value': 0.8011563706776392,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'react.js',
#      'value': 1.5791767192572184,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'sql',
#      'value': 0.6005164640112136,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'ux/ui',
#      'value': 0.5816053024025136,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'web',
#      'value': 1.605029746381749,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'xhtml',
#      'value': 0.11136692270702939,
#      'group': 0},
#     {'source': 'javascript',
#      'target': 'xml',
#      'value': 0.32313858312750854,
#      'group': 0},
#     {'source': 'jboss',
#      'target': 'struts',
#      'value': 0.26248857074339915,
#      'group': 0},
#     {'source': 'jboss',
#      'target': 'tomcat',
#      'value': 2.1580968975795956,
#      'group': 0},
#     {'source': 'jboss',
#      'target': 'weblogic',
#      'value': 1.3138247069676936,
#      'group': 0},
#     {'source': 'jboss',
#      'target': 'websphere',
#      'value': 0.2764008404189193,
#      'group': 0},
#     {'source': 'jdbc',
#      'target': 'jms',
#      'value': 0.5583759828445838,
#      'group': 0},
#     {'source': 'jdbc',
#      'target': 'jsp',
#      'value': 1.4869195233073507,
#      'group': 0},
#     {'source': 'jdbc',
#      'target': 'servlets',
#      'value': 0.5310900407750571,
#      'group': 0},
#     {'source': 'jdbc',
#      'target': 'spring',
#      'value': 0.2154637840627206,
#      'group': 0},
#     {'source': 'jdbc',
#      'target': 'struts',
#      'value': 0.2521953628064787,
#      'group': 0},
#     {'source': 'joomla',
#      'target': 'magento',
#      'value': 0.6245725444779795,
#      'group': 0},
#     {'source': 'joomla',
#      'target': 'mysql',
#      'value': 0.44459755449674454,
#      'group': 0},
#     {'source': 'joomla',
#      'target': 'php',
#      'value': 1.1757908495515652,
#      'group': 0},
#     {'source': 'joomla',
#      'target': 'wordpress',
#      'value': 2.6900199146369634,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'json',
#      'value': 0.6148939895820091,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'mvc',
#      'value': 1.511690767872724,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'mysql',
#      'value': 1.3750630501380994,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'net',
#      'value': 0.4487643980099948,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'php',
#      'value': 1.6576487917333727,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'sql',
#      'value': 0.23530443612379395,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'wcf',
#      'value': 0.3761833277539304,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'web',
#      'value': 1.291346695702657,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'wordpress',
#      'value': 0.4404468712410988,
#      'group': 0},
#     {'source': 'jquery',
#      'target': 'xml',
#      'value': 0.24539958569025122,
#      'group': 0},
#     {'source': 'json',
#      'target': 'rest',
#      'value': 0.40781570436366954,
#      'group': 0},
#     {'source': 'json',
#      'target': 'sdk',
#      'value': 0.8867921131534797,
#      'group': 0},
#     {'source': 'json',
#      'target': 'sqlite',
#      'value': 0.36842769120511976,
#      'group': 0},
#     {'source': 'json',
#      'target': 'xml',
#      'value': 2.0624253926611402,
#      'group': 0},
#     {'source': 'jsp',
#      'target': 'servlets',
#      'value': 2.6515920397947395,
#      'group': 0},
#     {'source': 'jsp',
#      'target': 'spring',
#      'value': 0.8750835715042976,
#      'group': 0},
#     {'source': 'jsp',
#      'target': 'struts',
#      'value': 2.17981544822639,
#      'group': 0},
#     {'source': 'junit',
#      'target': 'maven',
#      'value': 0.9900758111676262,
#      'group': 0},
#     {'source': 'junit',
#      'target': 'spring',
#      'value': 0.9651564076346034,
#      'group': 0},
#     {'source': 'lan', 'target': 'wan', 'value': 2.902708783416782, 'group': 0},
#     {'source': 'laravel',
#      'target': 'php',
#      'value': 1.8614295461966117,
#      'group': 0},
#     {'source': 'laravel',
#      'target': 'zend',
#      'value': 0.20895236641917098,
#      'group': 0},
#     {'source': 'linq',
#      'target': 'mvc',
#      'value': 0.8178865447271583,
#      'group': 0},
#     {'source': 'linq',
#      'target': 'net',
#      'value': 0.9528412046270602,
#      'group': 0},
#     {'source': 'linq',
#      'target': 'wcf',
#      'value': 1.1071329447929723,
#      'group': 0},
#     {'source': 'linq',
#      'target': 'wpf',
#      'value': 0.2590441602528127,
#      'group': 0},
#     {'source': 'linux',
#      'target': 'perl',
#      'value': 0.7791507047072161,
#      'group': 0},
#     {'source': 'linux',
#      'target': 'scripting',
#      'value': 0.634326610999296,
#      'group': 0},
#     {'source': 'linux',
#      'target': 'shell',
#      'value': 0.5910241405430819,
#      'group': 0},
#     {'source': 'linux',
#      'target': 'unix',
#      'value': 2.1258339181739716,
#      'group': 0},
#     {'source': 'linux',
#      'target': 'windows',
#      'value': 1.1274509161734299,
#      'group': 0},
#     {'source': 'ml/ai',
#      'target': 'mining',
#      'value': 0.3722979752035315,
#      'group': 0},
#     {'source': 'ml/ai',
#      'target': 'python',
#      'value': 0.1709288856202395,
#      'group': 0},
#     {'source': 'ml/ai',
#      'target': 'r',
#      'value': 0.2799128273554494,
#      'group': 0},
#     {'source': 'magento',
#      'target': 'php',
#      'value': 0.5957610808825686,
#      'group': 0},
#     {'source': 'magento',
#      'target': 'wordpress',
#      'value': 0.694470069759759,
#      'group': 0},
#     {'source': 'maven',
#      'target': 'spring',
#      'value': 0.9164646818356178,
#      'group': 0},
#     {'source': 'microservices',
#      'target': 'spring',
#      'value': 0.4158786443193132,
#      'group': 0},
#     {'source': 'mobile',
#      'target': 'sdk',
#      'value': 0.790110782688649,
#      'group': 0},
#     {'source': 'modeling',
#      'target': 'sas',
#      'value': 0.18340689339107297,
#      'group': 0},
#     {'source': 'modeling',
#      'target': 'statistics',
#      'value': 0.5000501696541502,
#      'group': 0},
#     {'source': 'mongodb',
#      'target': 'node.js',
#      'value': 0.5629858109458565,
#      'group': 0},
#     {'source': 'mongodb',
#      'target': 'nosql',
#      'value': 1.4543372123305611,
#      'group': 0},
#     {'source': 'ms',
#      'target': 'office',
#      'value': 2.794711533443915,
#      'group': 0},
#     {'source': 'ms',
#      'target': 'powerpoint',
#      'value': 0.22532628758849782,
#      'group': 0},
#     {'source': 'ms',
#      'target': 'sql',
#      'value': 0.22202600347728443,
#      'group': 0},
#     {'source': 'ms',
#      'target': 'word',
#      'value': 1.1138793015863966,
#      'group': 0},
#     {'source': 'mvc', 'target': 'net', 'value': 2.290976503523393, 'group': 0},
#     {'source': 'mvc',
#      'target': 'server',
#      'value': 0.2869778751429821,
#      'group': 0},
#     {'source': 'mvc',
#      'target': 'sql',
#      'value': 0.6100828461359417,
#      'group': 0},
#     {'source': 'mvc',
#      'target': 'wcf',
#      'value': 1.5200122288681528,
#      'group': 0},
#     {'source': 'mysql',
#      'target': 'php',
#      'value': 2.8213969212259924,
#      'group': 0},
#     {'source': 'mysql',
#      'target': 'wordpress',
#      'value': 0.36457241731837187,
#      'group': 0},
#     {'source': 'mysql',
#      'target': 'zend',
#      'value': 0.3839994734105251,
#      'group': 0},
#     {'source': 'net',
#      'target': 'oracle',
#      'value': 1.0672007181238465,
#      'group': 0},
#     {'source': 'net', 'target': 'pmp', 'value': 2.01070264172368, 'group': 0},
#     {'source': 'net',
#      'target': 'python',
#      'value': 0.9104839576127604,
#      'group': 0},
#     {'source': 'net',
#      'target': 'server',
#      'value': 1.8711126790913712,
#      'group': 0},
#     {'source': 'net',
#      'target': 'sql',
#      'value': 2.3481979926406145,
#      'group': 0},
#     {'source': 'net', 'target': 'vb', 'value': 1.2544607761159707, 'group': 0},
#     {'source': 'net',
#      'target': 'vb.net',
#      'value': 1.596378562184668,
#      'group': 0},
#     {'source': 'net',
#      'target': 'wcf',
#      'value': 1.8230711016549943,
#      'group': 0},
#     {'source': 'net',
#      'target': 'wpf',
#      'value': 0.3455191699645723,
#      'group': 0},
#     {'source': 'network',
#      'target': 'wan',
#      'value': 0.16169683854098388,
#      'group': 0},
#     {'source': 'node.js',
#      'target': 'react.js',
#      'value': 2.031271229390879,
#      'group': 0},
#     {'source': 'objectoriented',
#      'target': 'programming',
#      'value': 1.7946910130704234,
#      'group': 0},
#     {'source': 'objective',
#      'target': 'swift',
#      'value': 2.8482905071353786,
#      'group': 0},
#     {'source': 'online',
#      'target': 'seo',
#      'value': 0.24879087243559786,
#      'group': 0},
#     {'source': 'online',
#      'target': 'social',
#      'value': 0.19289350661504368,
#      'group': 0},
#     {'source': 'oracle',
#      'target': 'plsql',
#      'value': 1.0410918036658097,
#      'group': 0},
#     {'source': 'oracle',
#      'target': 'pmp',
#      'value': 2.0728910821752264,
#      'group': 0},
#     {'source': 'oracle',
#      'target': 'python',
#      'value': 1.2254637170417362,
#      'group': 0},
#     {'source': 'oracle',
#      'target': 'sql',
#      'value': 1.4302306855185032,
#      'group': 0},
#     {'source': 'perl',
#      'target': 'scripting',
#      'value': 0.8634656721537329,
#      'group': 0},
#     {'source': 'perl',
#      'target': 'shell',
#      'value': 0.47410836512502086,
#      'group': 0},
#     {'source': 'perl',
#      'target': 'unix',
#      'value': 0.654063640066844,
#      'group': 0},
#     {'source': 'perl',
#      'target': 'verilog',
#      'value': 0.4280911574913777,
#      'group': 0},
#     {'source': 'php',
#      'target': 'web',
#      'value': 0.34175274213201945,
#      'group': 0},
#     {'source': 'php',
#      'target': 'wordpress',
#      'value': 2.201703445973203,
#      'group': 0},
#     {'source': 'php',
#      'target': 'zend',
#      'value': 1.2399059079353443,
#      'group': 0},
#     {'source': 'pl',
#      'target': 'plsql',
#      'value': 1.570625800783311,
#      'group': 0},
#     {'source': 'pmp',
#      'target': 'python',
#      'value': 2.104533268416413,
#      'group': 0},
#     {'source': 'pmp',
#      'target': 'xhtml',
#      'value': 0.840498998932074,
#      'group': 0},
#     {'source': 'powerpoint',
#      'target': 'word',
#      'value': 0.7467769365895989,
#      'group': 0},
#     {'source': 'ppc', 'target': 'sem', 'value': 2.302332033239682, 'group': 0},
#     {'source': 'ppc', 'target': 'seo', 'value': 1.702444922143366, 'group': 0},
#     {'source': 'programming',
#      'target': 'software',
#      'value': 0.31579359529367795,
#      'group': 0},
#     {'source': 'protocols',
#      'target': 'routing',
#      'value': 1.1898454950936104,
#      'group': 0},
#     {'source': 'qa', 'target': 'qc', 'value': 1.398522696398781, 'group': 0},
#     {'source': 'qa',
#      'target': 'selenium',
#      'value': 0.15864332834499267,
#      'group': 0},
#     {'source': 'queries',
#      'target': 'sql',
#      'value': 0.48700366402175055,
#      'group': 0},
#     {'source': 'r', 'target': 'sas', 'value': 0.6690690451277185, 'group': 0},
#     {'source': 'rest',
#      'target': 'soap',
#      'value': 2.05200029220158,
#      'group': 0},
#     {'source': 'rest',
#      'target': 'spring',
#      'value': 1.1618450087963463,
#      'group': 0},
#     {'source': 'routing',
#      'target': 'vpn',
#      'value': 1.1206519246249091,
#      'group': 0},
#     {'source': 'routing',
#      'target': 'wan',
#      'value': 0.3194589538626226,
#      'group': 0},
#     {'source': 'sas',
#      'target': 'statistics',
#      'value': 2.6388819759666777,
#      'group': 0},
#     {'source': 'sas',
#      'target': 'tableau',
#      'value': 0.2834384878512727,
#      'group': 0},
#     {'source': 'scala',
#      'target': 'spark',
#      'value': 2.3830683521542575,
#      'group': 0},
#     {'source': 'scripting', 'target': 'shell', 'value': 3.0, 'group': 0},
#     {'source': 'scripting',
#      'target': 'unix',
#      'value': 1.7573618885942182,
#      'group': 0},
#     {'source': 'sdk',
#      'target': 'sqlite',
#      'value': 1.7206084977316791,
#      'group': 0},
#     {'source': 'sem',
#      'target': 'seo',
#      'value': 2.5144611745316863,
#      'group': 0},
#     {'source': 'sem',
#      'target': 'social',
#      'value': 0.5446534911614904,
#      'group': 0},
#     {'source': 'seo',
#      'target': 'social',
#      'value': 1.80411430636262,
#      'group': 0},
#     {'source': 'server',
#      'target': 'sql',
#      'value': 2.576067245518847,
#      'group': 0},
#     {'source': 'server',
#      'target': 'windows',
#      'value': 0.2976789332732876,
#      'group': 0},
#     {'source': 'servlets',
#      'target': 'spring',
#      'value': 0.8692633355265148,
#      'group': 0},
#     {'source': 'servlets',
#      'target': 'struts',
#      'value': 1.0281887427465863,
#      'group': 0},
#     {'source': 'shell',
#      'target': 'unix',
#      'value': 2.020966954036059,
#      'group': 0},
#     {'source': 'soc',
#      'target': 'verilog',
#      'value': 1.970041932129856,
#      'group': 0},
#     {'source': 'spring',
#      'target': 'struts',
#      'value': 1.7389137846735478,
#      'group': 0},
#     {'source': 'spring',
#      'target': 'tomcat',
#      'value': 0.13463773826972011,
#      'group': 0},
#     {'source': 'sql',
#      'target': 'wcf',
#      'value': 0.4956844246754105,
#      'group': 0},
#     {'source': 'sql',
#      'target': 'xml',
#      'value': 0.15560166056909974,
#      'group': 0},
#     {'source': 'ssis',
#      'target': 'ssrs',
#      'value': 2.9440811842741956,
#      'group': 0},
#     {'source': 'system',
#      'target': 'verilog',
#      'value': 0.1771436458735794,
#      'group': 0},
#     {'source': 'tableau',
#      'target': 'visualization',
#      'value': 0.46559463668522294,
#      'group': 0},
#     {'source': 'tomcat',
#      'target': 'weblogic',
#      'value': 1.0153855715605142,
#      'group': 0},
#     {'source': 'troubleshooting',
#      'target': 'windows',
#      'value': 0.11711698335627359,
#      'group': 0},
#     {'source': 'ux/ui',
#      'target': 'web',
#      'value': 0.10282518843918383,
#      'group': 0},
#     {'source': 'vb',
#      'target': 'vb.net',
#      'value': 2.9859387065491543,
#      'group': 0},
#     {'source': 'virtualization',
#      'target': 'vmware',
#      'value': 1.0540955336531348,
#      'group': 0},
#     {'source': 'vmware',
#      'target': 'windows',
#      'value': 0.3380009216260512,
#      'group': 0},
#     {'source': 'vpn', 'target': 'wan', 'value': 0.649100585074272, 'group': 0},
#     {'source': 'wan',
#      'target': 'wireless',
#      'value': 0.6392321450459897,
#      'group': 0},
#     {'source': 'wcf',
#      'target': 'wpf',
#      'value': 2.3713997029969325,
#      'group': 0},
#     {'source': 'weblogic',
#      'target': 'websphere',
#      'value': 0.3998151840870172,
#      'group': 0},
#     {'source': 'xhtml',
#      'target': 'xml',
#      'value': 0.8067114392049386,
#      'group': 0},
#     {'source': 'xml',
#      'target': 'xslt',
#      'value': 1.2326707825051264,
#      'group': 0}]}}}

# %% [markdown]
# ## Структура датасета
#
# На данном этапе необходимо определиться со структурой будущего датасета.
#
# В качестве примера был выбран формат предложенный сотрудниками HuggingFace в рамках проекта [Graph Datasets](https://huggingface.co/graphs-datasets), цель данного проекта - собирают разнообразную информацию, представленную в виде графов, после чего преобразовывать её и выполнять упаковку в формат датасета.
#
# Чтобы создать датасет описывающий граф технологии потребуются поля:
#
# - `node_feat` - список всех вершин графа, для каждой из них будет сгенерировано уникальное свойство (feature);
# - `edge_index` - список всех рёбер графа;
# - `edge_attr` - атрибуты рёбер, в данном случае вес;
# - `y` - уникальные метки рёбер, по которым их можно будет в дальнейшем идентифицировать;
# - `num_nodes` - количество вершин графа;
# - `num_edges` - количество рёбер графа.

# %% [markdown]
# ## Подготовка списка вершин
#
# Сначала необходимо выполнить процедуру токенизации вершин.
#
# Каждый токен будет представлять из себя пару число<->строка в которой число обозначает порядковый номер вершины в списке `nodes`, а строка будет описывать название вершины (название технологии).
#
# В дальнейшем это позволит описать список `node_index` и использовать его на этапе генерации признаков узлов.

# %%
for jd in JD_ANALYSIS_GRAPHS:
    graph_data = items[jd]['object']

    # Получаем список вершин преобразовав словарь в список
    items[jd]['node_list'] = [node['id'] for node in graph_data['nodes']]

    # Получим словарь вида id->name
    items[jd]['node_index'] = {index: node for index, node in enumerate(items[jd]['node_list'])}

    # Получим обратный словарь вида name->id
    items[jd]['node_mapping'] = {node_id: i for i, node_id in enumerate(items[jd]['node_list'])}

items['jd_data.json']['node_index']
# Out:
# {0: '.net',
#  1: 'actionscript',
#  2: 'adobe',
#  3: 'agile',
#  4: 'aix',
#  5: 'ajax',
#  6: 'algo',
#  7: 'altova',
#  8: 'amazon',
#  9: 'android',
#  10: 'ant',
#  11: 'antlr',
#  12: 'apache',
#  13: 'apex',
#  14: 'apl',
#  15: 'app',
#  16: 'asp.net',
#  17: 'asterdata',
#  18: 'atom',
#  19: 'awk',
#  20: 'aws',
#  21: 'backbone',
#  22: 'bash',
#  23: 'bdd',
#  24: 'bigtable',
#  25: 'blackberry',
#  26: 'bluetooth',
#  27: 'boost',
#  28: 'c',
#  29: 'cache',
#  30: 'cake',
#  31: 'cassandra',
#  32: 'celery',
#  33: 'cellular',
#  34: 'centos',
#  35: 'cfengine',
#  36: 'cisco',
#  37: 'clojure',
#  38: 'cloud',
#  39: 'cmake',
#  40: 'cms',
#  41: 'codeigniter',
#  42: 'coffeescript',
#  43: 'confluence',
#  44: 'couch',
#  45: 'couchdb',
#  46: 'css',
#  47: 'cucumber',
#  48: 'cython',
#  49: 'database',
#  50: 'dell',
#  51: 'dhcp',
#  52: 'dhtml',
#  53: 'directx',
#  54: 'django',
#  55: 'dns',
#  56: 'dom',
#  57: 'dreamweaver',
#  58: 'drupal',
#  59: 'eclipse',
#  60: 'ejb',
#  61: 'encryption',
#  62: 'erlang',
#  63: 'esx',
#  64: 'exim',
#  65: 'extjs',
#  66: 'fcoe',
#  67: 'flash',
#  68: 'flask',
#  69: 'fpga',
#  70: 'frontend',
#  71: 'ftp',
#  72: 'fx',
#  73: 'gcc',
#  74: 'git',
#  75: 'google',
#  76: 'gpu',
#  77: 'grails',
#  78: 'greenplum',
#  79: 'groovy',
#  80: 'guice',
#  81: 'gunicorn',
#  82: 'gwt',
#  83: 'hadoop',
#  84: 'hardware',
#  85: 'haskell',
#  86: 'hbase',
#  87: 'hibernate',
#  88: 'hp',
#  89: 'html',
#  90: 'hudson',
#  91: 'hypertable',
#  92: 'hyperv',
#  93: 'ibm',
#  94: 'iis',
#  95: 'ios',
#  96: 'ip',
#  97: 'iscsi',
#  98: 'istqb',
#  99: 'iwebkit',
#  100: 'j',
#  101: 'java',
#  102: 'javascript',
#  103: 'jboss',
#  104: 'jenkins',
#  105: 'jira',
#  106: 'jmeter',
#  107: 'jmock',
#  108: 'joomla',
#  109: 'jpa',
#  110: 'jprofile',
#  111: 'jquery',
#  112: 'jscript',
#  113: 'json',
#  114: 'jsp',
#  115: 'jsunit',
#  116: 'juice',
#  117: 'junit',
#  118: 'kafka',
#  119: 'kanban',
#  120: 'knockout',
#  121: 'labview',
#  122: 'lamp',
#  123: 'linux',
#  124: 'lisp',
#  125: 'loadrunner',
#  126: 'lua',
#  127: 'lucene',
#  128: 'mapreduce',
#  129: 'maven',
#  130: 'mdx',
#  131: 'microsoft',
#  132: 'middleware',
#  133: 'mongodb',
#  134: 'mpeg',
#  135: 'msbuild',
#  136: 'mvc',
#  137: 'mysql',
#  138: 'nant',
#  139: 'networking',
#  140: 'nfs',
#  141: 'nginx',
#  142: 'nhibernate',
#  143: 'nlp',
#  144: 'node',
#  145: 'nosql',
#  146: 'nunit',
#  147: 'objectivec',
#  148: 'objectorientated',
#  149: 'ocaml',
#  150: 'opencl',
#  151: 'opengl',
#  152: 'oracle',
#  153: 'pci',
#  154: 'pentaho',
#  155: 'perl',
#  156: 'photoshop',
#  157: 'php',
#  158: 'phpunit',
#  159: 'pig',
#  160: 'pki',
#  161: 'posix',
#  162: 'postfix',
#  163: 'postgresql',
#  164: 'powershell',
#  165: 'puppet',
#  166: 'pxe',
#  167: 'python',
#  168: 'q/a',
#  169: 'qmail',
#  170: 'qtp',
#  171: 'rabbitmq',
#  172: 'rake',
#  173: 'rc',
#  174: 'rdms',
#  175: 'red',
#  176: 'redis',
#  177: 'rspec',
#  178: 'rss',
#  179: 'ruby',
#  180: 'salesforce',
#  181: 'samba',
#  182: 'sass',
#  183: 'scala',
#  184: 'scrum',
#  185: 'security',
#  186: 'sed',
#  187: 'selenium',
#  188: 'seo',
#  189: 'server',
#  190: 'sharepoint',
#  191: 'shell',
#  192: 'silverlight',
#  193: 'sinatra',
#  194: 'sip',
#  195: 'snmp',
#  196: 'solaris',
#  197: 'specflow',
#  198: 'spring',
#  199: 'sql',
#  200: 'squid',
#  201: 'ssas',
#  202: 'ssh',
#  203: 'ssis',
#  204: 'ssl',
#  205: 'ssrs',
#  206: 'stl',
#  207: 'svg',
#  208: 'svn',
#  209: 'symbian',
#  210: 'symfony',
#  211: 'systemc',
#  212: 'talend',
#  213: 'tck',
#  214: 'tcl',
#  215: 'tcp',
#  216: 'tdd',
#  217: 'tk',
#  218: 'tomcat',
#  219: 'toolchain',
#  220: 'ttl',
#  221: 'ubuntu',
#  222: 'udp',
#  223: 'ui',
#  224: 'umbraco',
#  225: 'umts',
#  226: 'unfuddle',
#  227: 'unix',
#  228: 'ux',
#  229: 'vagrant',
#  230: 'vb',
#  231: 'vb.net',
#  232: 'vbs',
#  233: 'vhdl',
#  234: 'vi',
#  235: 'vmware',
#  236: 'voip',
#  237: 'watir',
#  238: 'wcf',
#  239: 'weblogic',
#  240: 'wifi',
#  241: 'winrunner',
#  242: 'wordpress',
#  243: 'wpf',
#  244: 'xml',
#  245: 'yii',
#  246: 'yui',
#  247: 'zend',
#  248: 'zenoss'}

# %% [markdown]
# Теперь необходимо преобразовать идентификаторы узлов бинарный формат, поскольку количество вершин в обоих графах не превышает 256 преобразуем идентификаторы в 8-битные последовательности нулей и единиц, кодирующие каждое число.

# %%
import torch

for jd in JD_ANALYSIS_GRAPHS:
    node_list = items[jd]['node_list']

    # Получим для каждой вершины её параметры
    items[jd]['node_feat'] = torch.randn(len(node_list), 1)

items['jd_data.json']['node_feat']
# Out:
# tensor([[-0.1946],
#         [ 0.9171],
#         [ 0.9830],
#         [-1.7282],
#         [ 0.2771],
#         [ 0.4833],
#         [ 0.4328],
#         [ 1.7577],
#         [-1.7494],
#         [ 1.7087],
#         [ 1.0312],
#         [ 0.1590],
#         [ 2.3568],
#         [ 0.8845],
#         [ 1.0778],
#         [-0.6736],
#         [ 1.0762],
#         [ 0.0874],
#         [ 0.9510],
#         [-0.2769],
#         [-0.0159],
#         [ 1.1680],
#         [-0.4150],
#         [ 0.4626],
#         [ 1.3402],
#         [-0.5328],
#         [-0.3965],
#         [ 0.0970],
#         [-0.4747],
#         [ 1.9702],
#         [-2.2505],
#         [-0.2692],
#         [ 1.1352],
#         [-0.3500],
#         [-0.8045],
#         [ 1.1317],
#         [-0.8969],
#         [-1.4110],
#         [-0.6902],
#         [ 1.1639],
#         [-1.6999],
#         [ 2.0701],
#         [-0.0133],
#         [-0.7177],
#         [-0.6725],
#         [ 0.8724],
#         [-0.5425],
#         [-0.8251],
#         [-2.0510],
#         [-0.9113],
#         [-0.0713],
#         [-1.0114],
#         [ 0.8787],
#         [ 0.3183],
#         [-0.5961],
#         [-0.0036],
#         [-0.0105],
#         [ 0.8907],
#         [ 1.2828],
#         [-0.4070],
#         [ 0.3067],
#         [-0.3006],
#         [-0.8625],
#         [ 0.7929],
#         [-0.2811],
#         [ 1.2497],
#         [-1.5841],
#         [ 1.0049],
#         [-0.4717],
#         [ 0.7096],
#         [ 0.8173],
#         [-0.5955],
#         [ 0.3696],
#         [ 2.0878],
#         [-0.7950],
#         [ 0.7142],
#         [ 0.7719],
#         [-0.2488],
#         [-1.0221],
#         [ 0.2084],
#         [-0.4229],
#         [ 0.5407],
#         [-0.3836],
#         [ 0.3286],
#         [-0.6207],
#         [ 1.1755],
#         [-0.5914],
#         [ 0.3498],
#         [-2.0316],
#         [ 0.3395],
#         [ 0.0481],
#         [-1.2884],
#         [-1.4514],
#         [ 1.1378],
#         [-0.5228],
#         [ 0.9374],
#         [ 1.4695],
#         [ 0.7568],
#         [ 0.1350],
#         [-0.3226],
#         [ 2.6711],
#         [-0.3137],
#         [ 0.1058]])

# %% [markdown]
# ## Подготовка рёбер
#
# На данном этапе у нас уже имеется список вершин и различные словари для работы с ними, поэтому приступим к этапу преобразования списка `links` в формат связей числовых идентификаторов. Помимо этого потребуется извлечь веса рёбер из поля `value`.

# %%
for jd in JD_ANALYSIS_GRAPHS:
    graph_data = items[jd]['object']
    node_mapping = items[jd]['node_mapping']

    items[jd]['edge_index'] = [[node_mapping[link['source']], node_mapping[link['target']]] for link in graph_data['links']]
    items[jd]['edge_attr'] = [link['value'] for link in graph_data['links']]

items['jd_data.json']['edge_index'], items['jd_data.json']['edge_attr']
# Out:
# ([[0, 3],
#   [0, 5],
#   [0, 16],
#   [0, 28],
#   [0, 46],
#   [0, 89],
#   [0, 102],
#   [0, 111],
#   [0, 131],
#   [0, 136],
#   [0, 142],
#   [0, 146],
#   [0, 184],
#   [0, 189],
#   [0, 190],
#   [0, 192],
#   [0, 199],
#   [0, 216],
# %%
import pyarrow as pa

# Ключи которые нас интересуют
keys = ['node_feat', 'node_index', 'edge_index', 'edge_attr', 'node_list']

# Инициализируем объект списков
t_data = {key: [] for key in keys + ['num_nodes', 'num_edges']}

# Пройдёмся по каждому подготовленному дотасету
for jd in JD_ANALYSIS_GRAPHS:
    for key in keys:
        if key == 'node_feat':
            t_data[key].append(items[jd][key].tolist())
        else:
            t_data[key].append(items[jd][key])

    # Посчитаем 'num_nodes' и 'num_edges'
    t_data['num_nodes'].append(len(items[jd]['node_index']))
    t_data['num_edges'].append(len(items[jd]['edge_index']))

# Соберём таблицу с двумя графами
large_table = pa.table(
    data={
        'name': JD_ANALYSIS_GRAPHS,
        'node_feat': t_data['node_feat'],
        'edge_index': t_data['edge_index'],
        'edge_attr': t_data['edge_attr'],
        'y': t_data['node_list'],
        'num_nodes': t_data['num_nodes'],
        'num_edges': t_data['num_edges'],
    },
    schema=pa.schema([
        pa.field(name="name", type=pa.string()),
        pa.field(name="node_feat", type=pa.list_(pa.list_(pa.float64()))),
        pa.field(name="edge_index", type=pa.list_(pa.list_(pa.int64()))),
        pa.field(name="edge_attr", type=pa.list_(pa.float64())),
        pa.field(name="y", type=pa.list_(pa.string())),
        pa.field(name="num_nodes", type=pa.int64()),
        pa.field(name="num_edges", type=pa.int64()),
    ]),
)

large_table
# Out:
# pyarrow.Table
# name: string
# node_feat: list<item: list<item: double>>
#   child 0, item: list<item: double>
#       child 0, item: double
# edge_index: list<item: list<item: int64>>
#   child 0, item: list<item: int64>
#       child 0, item: int64
# edge_attr: list<item: double>
#   child 0, item: double
# y: list<item: string>
#   child 0, item: string
# num_nodes: int64
# num_edges: int64
# ----
# name: [["jd_data.json","jd_data2.json"]]
# node_feat: [[[[-0.1946171522140503],[0.9170738458633423],...,[-0.31372490525245667],[0.10580454766750336]],[[0.9915452599525452],[-2.989278554916382],...,[0.4129026532173157],[1.4734593629837036]]]]
# edge_index: [[[[0,3],[0,5],...,[230,231],[238,243]],[[0,12],[0,92],...,[173,174],[174,175]]]]
# edge_attr: [[[0.8372881714433367,0.44773339967812265,2.972593634658615,2.8562696820640907,1.122948220895545,...,0.3043251194585422,1.9172178562464413,1.8420892465857406,3,2.676464392590603],[1.2988102697554484,0.9963664180718397,0.7956228463571555,0.6893503066233211,1.775953923744971,...,0.6392321450459897,2.3713997029969325,0.3998151840870172,0.8067114392049386,1.2326707825051264]]]
# y: [[[".net","actionscript","adobe","agile","aix",...,"xml","yii","yui","zend","zenoss"],["ado","adobe","adwords","ajax","algorithms",...,"wpf","xhtml","xml","xslt","zend"]]]
# num_nodes: [[249,177]]
# num_edges: [[668,415]]

# %% [markdown]
# ## Создание таблицы маленьких графов
#
# Сначала сгенерируем 1000 подграфов из каждого большого графа, после чего соберём их в таблицу.

# %%
from simple_gnn.graph.generate_subgraphs import *
from simple_gnn.dataset.jd_dataset import *

# Сгенерируем 1000 подграфов из каждого большого графа
for jd in JD_ANALYSIS_GRAPHS:
    keys = ['name', 'node_feat', 'node_index', 'edge_index', 'edge_attr', 'node_list']
    t_data = {key: [] for key in keys + ['num_nodes', 'num_edges']}
    graph_data = items[jd]['object']
    subgraphs = generate_subgraphs(graph_data, 1000, 2, 15)
    for (index, subgraph) in enumerate(subgraphs):

        # Build edge index
        subgraph_edge_index = []
        for link in subgraph['links']:
            source_idx = items[jd]['node_mapping'].get(link['source'])
            target_idx = items[jd]['node_mapping'].get(link['target'])
            # Add edge only if both nodes are on the subgraph
            if source_idx is not None and target_idx is not None:
                subgraph_edge_index.append([source_idx, target_idx])

        # Build edges weights
        subgraph_edge_attr = [link['value'] for link in subgraph['links']]

        # List of nodes 
        subgraph_node_list = [link['id'] for link in subgraph['nodes']]

        # Convert subgraphs nodes of the small graph
        subgraph_node_index = []
        for link in subgraph['nodes']:
            node_idx = items[jd]['node_mapping'].get(link['id'])
            if node_idx is not None:
                subgraph_node_index.append(node_idx)

        # Make a mask for the subgraph nodes
        subgraph_mask = torch.zeros_like(items[jd]['node_feat'])
        for idx in subgraph_node_index:
            subgraph_mask[idx] = 1
        subgraph_masked_features = items[jd]['node_feat'] * subgraph_mask

        t_data['name'].append(jd)
        t_data['node_feat'].append(subgraph_masked_features.tolist())
        t_data['node_index'].append(subgraph_node_index)
        t_data['node_list'].append(subgraph_node_list)
        t_data['edge_index'].append(subgraph_edge_index)
        t_data['edge_attr'].append(subgraph_edge_attr)
        t_data['num_nodes'].append(len(subgraph_node_index))
        t_data['num_edges'].append(len(subgraph_edge_index))

        items[jd]['subgraph_table'] = pa.table(
            data={
                'name': t_data['name'],
                'node_feat': t_data['node_feat'],
                'edge_index': t_data['edge_index'],
                'edge_attr': t_data['edge_attr'],
                'y': t_data['node_list'],
                'num_nodes': t_data['num_nodes'],
                'num_edges': t_data['num_edges'],
            },
            schema=pa.schema([
                pa.field(name="name", type=pa.string()),
                pa.field(name="node_feat", type=pa.list_(pa.list_(pa.float64()))),
                pa.field(name="edge_index", type=pa.list_(pa.list_(pa.int64()))),
                pa.field(name="edge_attr", type=pa.list_(pa.float64())),
                pa.field(name="y", type=pa.list_(pa.string())),
                pa.field(name="num_nodes", type=pa.int64()),
                pa.field(name="num_edges", type=pa.int64()),
            ]),
        )

# %%
from datasets import Dataset, DatasetDict

# Преобразование объектов PyArrow в объекты датасета Hugging Face
ds_large = Dataset(large_table)
ds_jd_data = Dataset(items["jd_data.json"]['subgraph_table'])
ds_jd_data2 = Dataset(items["jd_data2.json"]['subgraph_table'])

# Объединение отдельных датасетов в один датасет с разными сплитами
dataset_dict = DatasetDict({
    'train': ds_large,
    'jd_data.json': ds_jd_data,
    'jd_data2.json': ds_jd_data2
})

# Выгрузка датасета на Hugging Face
dataset_dict.push_to_hub('evilfreelancer/jd_analysis_graphs')
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/791 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/evilfreelancer/jd_analysis_graphs/commit/e06107e4a7927066b6a9f3a26c77d8c3867b4e59', commit_message='Upload dataset', commit_description='', oid='e06107e4a7927066b6a9f3a26c77d8c3867b4e59', pr_url=None, pr_revision=None, pr_num=None)
