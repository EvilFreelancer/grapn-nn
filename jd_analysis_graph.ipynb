# %%
from graph.visualizer import visualize
from simple_gnn.dataset.jd_dataset import load_jda

jd = "jd_data2.json"
jd_data = load_jda(jd)
visualize(jd_data, True)

# %%
import json

from simple_gnn.graph.generate_subgraphs import generate_subgraphs
subgraphs = generate_subgraphs(jd_data, 5, 3, 5)
for subgraph in subgraphs:
    print(subgraph)
    visualize(subgraph, render=True, figsize=(10, 10))
json.dump(subgraphs, open('subgraphs.json', 'w'))
# Out:
# {'nodes': [{'id': 'microservices'}, {'id': 'spring'}, {'id': 'jsp'}], 'links': [{'source': 'jsp', 'target': 'spring', 'value': 0.8750835715042976, 'group': 0}, {'source': 'microservices', 'target': 'spring', 'value': 0.4158786443193132, 'group': 0}]}
# {'nodes': [{'id': 'embedded'}, {'id': 'firmware'}, {'id': 'c'}, {'id': 'pmp'}, {'id': 'server'}], 'links': [{'source': 'c', 'target': 'embedded', 'value': 0.4118393415331123, 'group': 0}, {'source': 'c', 'target': 'pmp', 'value': 0.6640477947144444, 'group': 0}, {'source': 'c', 'target': 'server', 'value': 0.32683253864982015, 'group': 0}, {'source': 'embedded', 'target': 'firmware', 'value': 1.666538525256444, 'group': 0}]}
# {'nodes': [{'id': 'jms'}, {'id': 'j2ee'}, {'id': 'ejb'}, {'id': 'rest'}], 'links': [{'source': 'ejb', 'target': 'j2ee', 'value': 0.6791702712325045, 'group': 0}, {'source': 'j2ee', 'target': 'jms', 'value': 0.21873851884875806, 'group': 0}, {'source': 'j2ee', 'target': 'rest', 'value': 0.2940980440976019, 'group': 0}]}
# {'nodes': [{'id': 'xhtml'}, {'id': 'ajax'}, {'id': 'php'}], 'links': [{'source': 'ajax', 'target': 'php', 'value': 1.0090212027262375, 'group': 0}, {'source': 'ajax', 'target': 'xhtml', 'value': 0.977567693270758, 'group': 0}]}
# {'nodes': [{'id': 'scripting'}, {'id': 'unix'}, {'id': 'linux'}], 'links': [{'source': 'linux', 'target': 'scripting', 'value': 0.634326610999296, 'group': 0}, {'source': 'linux', 'target': 'unix', 'value': 2.1258339181739716, 'group': 0}, {'source': 'scripting', 'target': 'unix', 'value': 1.7573618885942182, 'group': 0}]}
